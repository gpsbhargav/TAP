# %% [markdown]
# # Goal: Take the preprocessed data, format it like the predictions and pass them to the evaluator

# %%
from collections import Counter
import string
import re
import argparse
import json
import sys
import numpy as np
import nltk
import random
import math
import os
import pickle
from tqdm import tqdm, trange

import pdb

from pytorch_pretrained_bert import BertTokenizer

# %%
def pickler(path,pkl_name,obj):
    with open(os.path.join(path, pkl_name), 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def unpickler(path,pkl_name):
    with open(os.path.join(path, pkl_name) ,'rb') as f:
        obj = pickle.load(f)
    return obj

# %%
class PredictionFormatter:
    
    def __init__(self):
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
        self.max_answer_length = 20 #options.max_answer_length
        
    def un_tokenize(self,ids, tokens_to_text_mapping, bert_tokenizer):
        out_list = []
        start = 0
        end = start
        while (start < len(ids)) and (end < len(ids)):
            i = len(ids)
            decoded_anything = False
            while (decoded_anything == False) and (i > start):
                if(tuple(ids[start:i]) in tokens_to_text_mapping.keys()):
                    out_list.append(tokens_to_text_mapping[tuple(ids[start:i])])
                    decoded_anything = True
                else:
                    i -= 1
            if(decoded_anything == False):
                out_list.append(bert_tokenizer.convert_ids_to_tokens([ids[start]])[0])
                start += 1
                end = start
            else:
                start = i
                end = i
        return " ".join(out_list)

    def is_word_split(self,word):
        if(len(word) < 2):
            return False
        else:
            return (word[0] == '#' and word[1] == '#')

    def combine_word_pieces(self, sentence):
        # the first word cant start with '##'
        out_tokens = []
        for token in sentence:
            if(not self.is_word_split(token)):
                out_tokens.append((token))
            else:
                out_tokens[-1] += token[2:]
        return out_tokens
        
    def convert_indices_to_text(self, sentence, start, end, tokens_to_text_mapping):
        ''' (sentence, [10, 12]) --> ['runn', '##ing', 'race'] --> ['running', 'race']
        --> "running race" '''
        text = self.tokenizer.convert_ids_to_tokens(sentence)
        true_start = start
        if(self.is_word_split(text[start])):
            for i in range(1,start):
                if(not self.is_word_split(text[start-i])):
                    true_start = start-i
                    break
        
        true_end = end
        for i in range(end+1, len(sentence)):
            if(not self.is_word_split(text[i])):
                true_end = i-1
                break

        proper_text = self.un_tokenize(sentence[true_start:true_end+1], tokens_to_text_mapping, self.tokenizer)
        return proper_text
        

    def find_most_confident_span(self, start_scores, end_scores):
        ''' 
        Inputs: masked start_scores and end_scores of a single example
        Output: (i,j) pairs having highest Pr(i) + Pr(j)
        '''
        assert(len(start_scores) == len(end_scores))
        best_start = 0
        best_stop = 0
        best_confidence = 0
        for i in range(len(start_scores)):
            for j in range(i, min(len(end_scores), i + self.max_answer_length)):
                if(start_scores[i] + end_scores[j] > best_confidence):
                    best_start = i
                    best_stop = j
                    best_confidence = start_scores[i] + end_scores[j]
        return best_start, best_stop

    def format_prediction(self, yes_no_span, start_scores, end_scores, sequences, tokens_to_text_mappings, official_evalutation=True):
        '''
        input: all numpy arrays
        output: list of answer in english (ex: ["polar bear", "emperor penguin"])
        '''
        answers = []
        assert(len(yes_no_span) == len(start_scores) == len(end_scores) == len(sequences))

        for i in range(len(yes_no_span)):
            if(official_evalutation):
                yns = yes_no_span[i].argmax(axis=-1)
                if(yns == 0):
                    answers.append("yes")
                    continue
                elif(yns == 1):
                    answers.append("no")
                    continue
            
            start, end = self.find_most_confident_span(start_scores[i], end_scores[i])

            ans = self.convert_indices_to_text(sequences[i], start, end, tokens_to_text_mappings[i])
            answers.append(ans.replace(" ##",'').replace("##",''))
        
        assert(len(answers) == len(sequences))

        return answers


class Evaluator:
    
    ''' Adapted from the official HotpotQA evaluation script ''' 

    def normalize_answer(self, s):
        def remove_articles(text):
            return re.sub(r'\b(a|an|the)\b', ' ', text)

        def white_space_fix(text):
            return ' '.join(text.split())

        def remove_punc(text):
            exclude = set(string.punctuation)
            return ''.join(ch for ch in text if ch not in exclude)

        def lower(text):
            return text.lower()

        return white_space_fix(remove_articles(remove_punc(lower(s))))

    def f1_score(self,prediction, ground_truth):
        normalized_prediction = self.normalize_answer(prediction)
        normalized_ground_truth = self.normalize_answer(ground_truth)

        ZERO_METRIC = (0, 0, 0)

        if normalized_prediction in ['yes', 'no', 'noanswer'] and normalized_prediction != normalized_ground_truth:
            return ZERO_METRIC
        if normalized_ground_truth in ['yes', 'no', 'noanswer'] and normalized_prediction != normalized_ground_truth:
            return ZERO_METRIC

        prediction_tokens = normalized_prediction.split()
        ground_truth_tokens = normalized_ground_truth.split()
        common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
        num_same = sum(common.values())
        if num_same == 0:
            return ZERO_METRIC
        precision = 1.0 * num_same / len(prediction_tokens)
        recall = 1.0 * num_same / len(ground_truth_tokens)
        f1 = (2 * precision * recall) / (precision + recall)
        return f1, precision, recall

    def exact_match_score(self, prediction, ground_truth):
        return (self.normalize_answer(prediction) == self.normalize_answer(ground_truth))

    def compute_yes_no_span_em(self, gt, pred):
        pred_classes = pred.argmax(axis=-1)
        num_correct = 0
        for i in range(len(pred)):
            if(pred_classes[i] == gt[i]):
                num_correct += 1
        return num_correct/len(pred)

    def evaluate_answers_official(self, gold, prediction, question_indices, divide_by_len_pred = True):
        assert(len(gold) >= len(prediction))
        assert(len(prediction) == len(question_indices))
        
        metrics = {'em': 0, 'f1':0, 'precision':0, 'recall':0}
        
        indices_with_0_em = []
        
        for i in range(len(prediction)):
            em = self.exact_match_score(prediction[i], gold[question_indices[i]])
            f1, prec, recall = self.f1_score(prediction[i], gold[question_indices[i]])
            metrics['em'] += float(em)
            metrics['f1'] += f1
            metrics['precision'] += prec
            metrics['recall'] += recall
            if(em == 0):
                indices_with_0_em.append(i)
        
        for key in metrics.keys():
            if(divide_by_len_pred):
                metrics[key] /= len(prediction)
            else:
                metrics[key] /= len(gold)
        
        return metrics, indices_with_0_em
    
    def individual_question_metrics(self, gold, prediction, question_indices):
        assert(len(gold) >= len(prediction))
        assert(len(prediction) == len(question_indices))
        
        metrics = {'em': [], 'f1':[], 'precision':[], 'recall':[]}
        
        for i in range(len(prediction)):
            em = self.exact_match_score(prediction[i], gold[question_indices[i]])
            f1, prec, recall = self.f1_score(prediction[i], gold[question_indices[i]])
            metrics['em'].append(float(em))
            metrics['f1'].append(f1)
            metrics['precision'].append(prec)
            metrics['recall'].append(recall)
        
        return metrics
    
    def evaluate_full_recall_only(self, gold, prediction, question_indices, full_recall_indices, divide_by_len_pred = True):
        
        all_metrics = self.individual_question_metrics(gold, prediction, question_indices)
        
        for i in range(len(prediction)):
            if i not in full_recall_indices:
                all_metrics['em'][i] = 0.0
                all_metrics['f1'][i] = 0.0
                all_metrics['precision'][i] = 0.0
                all_metrics['recall'][i] = 0.0
        
        final_metrics = {}
        for key in all_metrics.keys():
            final_metrics[key] = sum(all_metrics[key])/len(gold)
        
        return final_metrics

# %%
def prepare_span_predictions(data):
    max_seq_len = data['max_seq_len']
    out_start_predictions = []
    out_end_predictions = []
    for i in range(len(data['answer_start_indices_offset'])):
        
        if(len(data['answer_start_indices_offset'][i]) == 0):
            start_indices = [0] * max_seq_len
            end_indices = [0] * max_seq_len
        else:
            start_indices = [0] * max_seq_len
            start_indices[data['answer_start_indices_offset'][i][0]] = 1.0

            end_indices = [0] * max_seq_len
            end_indices[data['answer_end_indices_offset'][i][0]] = 1.0
        
        out_start_predictions.append(start_indices)
        out_end_predictions.append(end_indices)
    
    return np.array(out_start_predictions), np.array(out_end_predictions)

# %%
def prepare_yes_no_span_pred(data):
    out_yns = []
    for i in range(len(data['yes_no_span'])):
        yns = [0,0,0]
        yns[data['yes_no_span'][i]] = 1
        out_yns.append(yns)
    return np.array(out_yns)

# %%
raw_data = unpickler('./', 'preprocessed_train.pkl')

# %%
start_predictions, end_predictions = prepare_span_predictions(raw_data)

# %%
yes_no_span_pred = prepare_yes_no_span_pred(raw_data)

# %%
formatter = PredictionFormatter()
pred_answers = formatter.format_prediction(yes_no_span_pred, start_predictions, 
                                           end_predictions, raw_data['question_context_sequences'],
                                          raw_data["ids_to_word_mappings"])

# %%
evaluator = Evaluator()
metrics, indices_with_0_em = evaluator.evaluate_answers_official(gold=raw_data['answer_string'], prediction=pred_answers, 
                                     question_indices=raw_data['question_indices'], divide_by_len_pred = True)

# %%
metrics
# Out:
# {'em': 0.9834268823275433,
#  'f1': 0.9864094607896177,
#  'precision': 0.9883172798223105,
#  'recall': 0.9866360440195813}

# %%
len(indices_with_0_em)
# Out:
# 1497

# %%
Counter([pred_answers[i] for i in indices_with_0_em])
# Out:
# Counter({'6 , 960': 1,
#          'Opéra': 1,
#          'Washington, d . c .': 10,
#          '167 , 446': 1,
#          'i - 90': 1,
#          'quinceanera': 1,
#          '3 , 544': 2,
#          'Robert': 1,
#          '39 , 134': 2,
#          '8 , 765 , 000': 1,
#          'banjo': 1,
#          "the Go - Go ' s": 1,
#          '13 - 18': 1,
#          'Best Young actor / Actress': 1,
#          'Na do - hyang': 1,
#          'American': 1,
#          'founded': 1,
#          'Primera division': 3,
#          "defence of fort m ' henry": 1,
#          '1 , 425': 1,
#          'Benares gharana': 1,
#          'Juan Nepomuceno Seguin': 1,
#          '8 , 711': 1,
#          'Shim hyung - rae': 1,
#          'traditionalist': 1,
#          'Gelsenkirchen, North rhine - westphalia': 1,
#          '15 , 023': 3,
#          '66 , 135': 1,
#          '124 , 775': 2,
#          'yu - gi - oh': 1,
#          '542 , 196': 1,
#          '2 , 416': 2,
#          'the': 37,
#          'two': 1,
#          '7 , 304': 3,
#          'Comedy': 1,
#          '87 , 643': 1,
#          "Brendan o ' brien": 1,
#          'choshu': 1,
#          '1985 – 1988': 1,
#          '35 , 000': 3,
#          '29 – 17': 1,
#          'mahmud - i - raqi': 1,
#          'besiktas': 2,
#          's - 2': 2,
#          '11 , 235': 2,
#          'from 1971 – 74': 1,
#          'Beninese': 1,
#          'flanker - c': 1,
#          'centre - back': 1,
#          '74 , 982': 1,
#          'u': 2,
#          'hawaii five - o': 2,
#          'Königsberg, Zürich and gottingen': 1,
#          'moliere': 1,
#          '"Master of My make - believe "': 1,
#          'Yang hyun - suk': 2,
#          '1942 - 45': 1,
#          'Wong kar - wai': 3,
#          'Hirsch harif': 1,
#          'Kang hyeong - cheol': 2,
#          '" k . r . "': 1,
#          'Modesto': 1,
#          '42 , 074': 1,
#          'zip - a - dee - doo - dah': 1,
#          'House of habsburg - lorraine': 1,
#          '1901 - 2': 1,
#          '54 , 462': 2,
#          '10 , 445': 1,
#          'moon hyung - joo': 1,
#          '2 , 045': 3,
#          'Tori': 1,
#          'Donald': 1,
#          '325 , 858': 1,
#          'Mötley crue': 1,
#          'Washington, d . c': 1,
#          'Heidelberg, baden - wurttemberg': 1,
#          'Rodolfo "Corky" Gonzáles': 1,
#          '1 , 862': 1,
#          '15 . 18': 1,
#          'on': 3,
#          'warrior': 1,
#          '114 , 297': 2,
#          '168 , 270': 1,
#          '39 , 843': 2,
#          '$ 25 , 000': 1,
#          '1 , 749': 1,
#          'The': 3,
#          'nineteen eighty - four': 2,
#          "jim ' ll Fix it": 1,
#          'herge': 1,
#          'Yim pil - sung': 1,
#          "jennifer ' s body": 1,
#          'churros': 1,
#          'jamon jamon': 1,
#          'cordoba': 1,
#          'Park sang - jun': 4,
#          '5 , 813': 1,
#          "Michigan's 14 congressional district": 1,
#          'marriage': 1,
#          '862 , 044': 2,
#          'black Panther party for self - defense': 1,
#          'James': 2,
#          '3 , 324': 1,
#          'Park heung - sik': 1,
#          '9 , 116': 1,
#          'division I - aa': 1,
#          'moon': 1,
#          'Advancing': 1,
#          "Danny o ' donoghue": 1,
#          'ǽ': 1,
#          '388 , 072': 1,
#          '39 - story': 2,
#          '"': 13,
#          'cache': 1,
#          'until': 1,
#          'Richard': 1,
#          '14 , 521': 1,
#          '57 , 363': 1,
#          "coup d ' etat": 1,
#          '1 , 234': 1,
#          'İstanbul basaksehir': 2,
#          '3 . 1 miles': 1,
#          'He batted and threw right- handed': 1,
#          'Théâtre': 1,
#          'North rhine - westphalia': 2,
#          'KMFDM': 1,
#          '625 , 249': 1,
#          'antievolution claims of young - Earth': 1,
#          '492 , 276': 1,
#          'Yuen woo - ping': 1,
#          '"August \' s rhapsody "': 1,
#          'Lee byung - hun': 1,
#          'Mike': 1,
#          'Luis bunuel': 1,
#          'gender - blind': 1,
#          'jadakiss': 1,
#          "coogan ' s bluff": 1,
#          'poisoner': 1,
#          'catch - 22': 3,
#          "Bruxner highway ' s": 1,
#          'Jung woo - sung': 1,
#          "Brian o ' nolan": 1,
#          '321 , 520': 1,
#          '2 , 478': 1,
#          'Park': 1,
#          'Alfred': 1,
#          '"Dùn eideann "': 1,
#          "80 ' s": 1,
#          '7 , 409': 1,
#          '37 , 669': 1,
#          'hanumatōdi': 1,
#          'Barrow - in - furness': 1,
#          'universitat Bern': 1,
#          'Elizabeth': 1,
#          'rikki - tikki - tavi': 1,
#          '1 , 297': 2,
#          'Yolanda': 1,
#          '29 , 480': 1,
#          "don ' t Look in the basement": 1,
#          'Olivia newton - john': 1,
#          'zurich': 1,
#          'Ceratopetalum': 1,
#          '67 , 292': 1,
#          'Alexander': 1,
#          "miller ' s crossing": 1,
#          '52 , 158': 2,
#          'Melish': 1,
#          'Alaskan': 2,
#          'LĪVE': 1,
#          '9 , 984': 1,
#          '6 , 161': 1,
#          'hiv / aids': 1,
#          'Alain robbe - grillet': 2,
#          '3 , 000': 1,
#          'Alvin': 1,
#          'right - handed': 1,
#          'He': 9,
#          '18 , 910': 1,
#          'Amelio Robles Ávila': 1,
#          'super - agent': 1,
#          'She': 2,
#          'Mucuchíes': 1,
#          'April Kepner m . d .': 1,
#          'score of 37 – 24': 1,
#          '16 , 264': 2,
#          'José Canseco': 2,
#          'harpsichordist': 1,
#          '104 , 155': 1,
#          "asia ' s 25 Greatest Actors of All time": 1,
#          'Rockfords': 1,
#          'Sir': 1,
#          'goiania': 1,
#          'Lennon – mccartney': 1,
#          '10 , 700': 1,
#          'Mark A.Z. dippe': 2,
#          'Kim kwang - sik': 1,
#          '9 , 392': 2,
#          'Erich von daniken': 1,
#          '= " Lycians " > Lycians': 1,
#          'singer - songwriter': 10,
#          '14 – 68': 1,
#          'Joseph bove': 2,
#          "Paul o ' neill": 1,
#          '2 , 571': 2,
#          '52 , 044': 2,
#          "africa ' s Che guevara": 1,
#          'a': 7,
#          'university of Nebraska – lincoln': 1,
#          "Sears, Belk, JCPenney, and dillard ' s": 1,
#          'Horizonte, ceara': 1,
#          'Kwak jae - yong': 4,
#          'Critics': 1,
#          '4 , 447': 1,
#          'Con te partiro': 2,
#          'flo - jo': 1,
#          'footballing': 1,
#          'Bae': 1,
#          'in': 2,
#          'Shilong': 1,
#          '70 , 603': 2,
#          '1667 – 1730 ad': 1,
#          '18 , 856': 1,
#          '81 , 405': 2,
#          '50 , 347': 1,
#          'Im sang - soo': 3,
#          '625 , 846': 1,
#          'ACF Fiorentina s . p . A.': 1,
#          '32 , 851': 1,
#          '1 , 108': 1,
#          "don ' t Give a monkey ' s": 1,
#          'Jason Chan chi - san': 1,
#          'Ansar al - sharia': 1,
#          'ac / dc': 1,
#          "Mama ' s Bank account": 1,
#          'pour le merite': 2,
#          'St. luke ’ s': 1,
#          '147 , 754': 1,
#          's . e . s .': 1,
#          '21 , 257': 1,
#          'Charlotte bronte': 1,
#          'Segunda division B – Group 4': 1,
#          'Uncle': 1,
#          'Marie Curie - sklodowska': 1,
#          'abjads': 1,
#          '28 , 653': 1,
#          '16 , 116': 2,
#          'Kim ki - duk': 3,
#          'It': 6,
#          "ocean ' s twelve": 1,
#          'Rachel': 1,
#          'el Sol de mexico': 1,
#          'Siân Gibson': 1,
#          '18 , 400': 1,
#          'Weserubung': 1,
#          'mid-1971 to mid - 2000': 1,
#          'Zvereva': 1,
#          'Tarō Ono': 1,
#          'Loretta Sánchez': 1,
#          'Najd and al - yamama': 1,
#          'of - 10': 1,
#          'conducator': 1,
#          "Dr. Dre, DJ Yella, and michel ' le": 1,
#          'Raul Malo': 1,
#          '157 , 505': 1,
#          'nearly 100 , 000': 2,
#          'Colm toibin': 1,
#          't - 50': 1,
#          '7 , 297': 1,
#          '13 - 0': 1,
#          '16 , 667': 1,
#          'Kim Jong-il (1941–2011) and Ko yong - hui': 1,
#          'Park chan - wook': 1,
#          'Bong joon - ho': 2,
#          'Osvaldo farres': 1,
#          'losing Ground: American social Policy 1950 – 1980': 1,
#          'neshnabe': 2,
#          '16 , 295': 1,
#          '90 , 928': 2,
#          'beavis and butt - head': 2,
#          'one57': 1,
#          '2 , 700': 1,
#          'Darling': 1,
#          'SÉCAM': 1,
#          '1 , 485': 1,
#          'Junji Itō': 1,
#          'barton - upon - irwell': 1,
#          '837 , 073': 2,
#          'engineering': 1,
#          'Eva Wilhelmina Julia von Bahr - bergius': 1,
#          '15 , 541': 1,
#          "Pee-wee ' s playhouse": 1,
#          'Nicolas Sarközy': 1,
#          '(': 1,
#          'AquaGUI': 1,
#          'Park Bo-young and Uhm ji - won': 1,
#          'L. a . law': 1,
#          '7 , 003': 1,
#          'anarcho - capitalism': 1,
#          'Won shin - yun': 1,
#          '國 家 代 [UNK]': 1,
#          "i ' ll Overcome Some day": 1,
#          '674 , 158': 2,
#          'memoirist': 1,
#          'Park bo - young': 1,
#          'Michael caton - jones': 1,
#          'comprendeme': 1,
#          'HMS "Justice" ( w - 140 )': 1,
#          'it': 1,
#          '249 , 042': 1,
#          '40 , 212': 2,
#          'mughdhorna': 1,
#          'Cameroonian': 2,
#          'saal - schutz': 1,
#          '21 , 447': 1,
#          '1 , 465': 1,
#          '1363 - 1364': 1,
#          'Ghent': 1,
#          'Mitsubishi F-2B': 1,
#          '16 : 9': 1,
#          'the Mórrígan': 1,
#          '18 , 548': 1,
#          'University of nebraska – lincoln': 1,
#          'Lee kyoung - mi': 1,
#          '86 , 112': 4,
#          '618 , 000': 1,
#          'Saffron': 1,
#          'Alekanetero': 1,
#          '147 , 972': 1,
#          '1 : 5': 1,
#          'Ivan': 1,
#          'z - boys': 1,
#          '3 – 1': 1,
#          'Isaac': 1,
#          'Ju kyung - jung': 1,
#          'Pashayis': 1,
#          'ragam - Thanam - Pallavi': 1,
#          '48 , 665': 1,
#          'Newport': 1,
#          'Segaworld': 1,
#          'Ostmärkische': 1,
#          '14 . 6': 1,
#          '1963 - 64': 1,
#          '26 , 600': 1,
#          '7 , 560': 1,
#          '" catch - 22 "': 1,
#          'TWICEcoaster': 1,
#          'iran': 1,
#          '7,000 to 20 , 300': 1,
#          'Chicago pile - 1': 2,
#          '120 , 000': 1,
#          'Scorpions': 1,
#          'Kang so - ra': 1,
#          'the Hunchback of Notre - dame': 1,
#          'Epstein': 1,
#          '594 . 11': 1,
#          'Thomas': 1,
#          'Le': 1,
#          'Chocolat': 1,
#          'Kim dae - seung': 1,
#          '226 , 322': 1,
#          'French Résistance': 1,
#          'Lee seok - hoon': 1,
#          'compiling a record of 9 – 5': 1,
#          'Ryoo jang - ha': 2,
#          'cheese - flavored': 1,
#          '6 , 986': 1,
#          'Alexandre': 1,
#          'was': 1,
#          'Walt': 1,
#          '4 . 9 %': 1,
#          '10 , 172': 2,
#          'Henrik': 1,
#          'murujabad / murtuzabad': 1,
#          '57 , 132': 1,
#          'Tōkyō Dome': 1,
#          'Yuzuru Hanyū': 1,
#          'Qatari side al - khor': 1,
#          '6 , 459': 1,
#          'brooklyn nine - nine': 1,
#          'kwik - e - mart': 1,
#          'piratbyran': 1,
#          'jay - z': 2,
#          'A.J. Benza': 1,
#          '187 , 105': 2,
#          '2 , 790': 1,
#          'Thekla': 1,
#          'ESPNU': 1,
#          "nothing ' s Gonna Change My Love For you": 1,
#          "bobb ' e says": 1,
#          '97 , 032': 1,
#          'mid - 1980s': 2,
#          'alexandre': 1,
#          '37 , 500': 1,
#          '33 , 600': 2,
#          '" amloði "': 1,
#          '67 , 044': 1,
#          'Tanzanian': 1,
#          '1 , 493 , 350': 1,
#          'woyzeck ’ s Last symphony': 1,
#          'Nnedi Okorafor - mbachu': 1,
#          'award': 1,
#          '783 , 969': 1,
#          '69 , 176': 1,
#          'soundscapes': 1,
#          'Yamaha yzf - r1': 1,
#          'Arvid': 1,
#          'over 18 , 000': 2,
#          'Eckerd': 1,
#          'twin - engine': 2,
#          'Yi': 1,
#          'King willem - alexander': 3,
#          '526 , 702': 1,
#          'its population was 13 , 347': 1,
#          'Erick Zonca': 1,
#          'the nf - 5': 1,
#          'Makaha Sons': 1,
#          '"Late night with Conan o \' brien "': 1,
#          'The x - files': 1,
#          'pol - ka': 1,
#          'spo': 1,
#          'p . o . d .': 2,
#          "ripley ' s Believe It or Not!": 1,
#          'develops': 1,
#          '8 , 966': 1,
#          'Peter': 1,
#          '9 , 117': 2,
#          '8 , 881': 1,
#          '114 , 000': 2,
#          'Rebecca akufo - addo': 1,
#          'Earl': 1,
#          '1 , 810 , 863': 1,
#          'Hong Kongers': 2,
#          'Cedric Gervais': 1,
#          'm * a * s * h': 1,
#          'paleo - indians': 1,
#          '32 , 736': 1,
#          'Kim jung - hwan': 2,
#          '1700 – 21': 1,
#          'crazy / beautiful': 2,
#          'between': 2,
#          '3 , 976 , 322': 2,
#          'Tyrolean': 1,
#          'pokemon': 1,
#          'Auguste and Louis Lumiere': 1,
#          'Segunda division': 1,
#          '1 , 145 , 956': 2,
#          '1996 - 2009': 1,
#          '2 , 791': 1,
#          '2010 – 12': 1,
#          'a & e': 1,
#          'Jean-Louis Kerouac': 1,
#          '13 - year - old': 1,
#          'Éric Cantona': 1,
#          '2 , 184': 1,
#          'winston - salem': 1,
#          'dreadnoughts': 1,
#          "Grey ' s anatomy": 1,
#          'his': 1,
#          'Nietzsche': 1,
#          '3 , 990': 1,
#          'battle of mazar - i - sharif': 1,
#          'k - os': 1,
#          'Moby - dick': 1,
#          'Rania': 1,
#          'forhan': 1,
#          '15 , 061': 1,
#          'slaughterhouse - five': 3,
#          '9 , 309': 1,
#          'one': 1,
#          'Pedro Ortiz de Pinedo': 1,
#          '1892 – 94': 1,
#          'Donizetti': 1,
#          'duke of Saxe-Coburg - saalfeld': 1,
#          'CJ e & m': 1,
#          '44 , 900': 1,
#          'Y.A. Tittle': 1,
#          'Jane': 1,
#          'oglaigh na heireann': 1,
#          'mas Que amor': 1,
#          '2 , 032': 1,
#          "rowan & Martin's laugh - in": 1,
#          'Deportivo alaves': 1,
#          'the sing - off': 1,
#          'In': 2,
#          'born 1985 – 89': 1,
#          'Shijiazhuang': 1,
#          'Bosanski Oštrodlaki gonic': 1,
#          '26 , 658': 1,
#          '3 . 8 %': 1,
#          'the Baby of macon': 1,
#          'Alois': 1,
#          'Kim sung - su': 2,
#          '287 , 822': 1,
#          'mini - marts': 1,
#          'Sierra': 1,
#          'Matthew': 1,
#          'Dodge': 1,
#          "george ' s Secret Key to the universe": 1,
#          'Tuxtla gutierrez': 1,
#          'Jo sung - hee': 2,
#          'Tisha Campbell - martin': 1,
#          '90 , 000': 3,
#          '2008 - 09': 1,
#          '16 , 921': 1,
#          '109 , 426': 1,
#          '57 , 000': 1,
#          '11 , 791': 1,
#          'd . a . n . c . e .': 1,
#          'Macfusion': 1,
#          '37 , 442': 2,
#          'Louis Cha leung - yung': 1,
#          "sawyer ' s": 1,
#          'l': 2,
#          '82 , 000': 1,
#          'pre - American Civil war': 1,
#          'Guatemalan': 1,
#          'Hôtel Rwanda': 1,
#          '73 , 021': 1,
#          'made': 1,
#          'Alfonso cuaron': 1,
#          "Hitler's dependable mouthpiece and habitual yes - man": 1,
#          'dusseldorf': 2,
#          'Vénus in Fur': 2,
#          '15 , 543': 1,
#          'Kington - blair - Oliphant': 1,
#          '47 – 0': 1,
#          'Moria casan': 1,
#          'Tel aviv - Yafo': 1,
#          '1964 - 2014': 1,
#          "l ' evolution creatrice": 1,
#          '2 , 526': 2,
#          'Miklós rozsa': 1,
#          "Wu cheng ' en": 1,
#          'dun libhse': 1,
#          'Winston Leonard spencer - Churchill': 1,
#          '1 , 632 , 934': 1,
#          'cisterns': 1,
#          "dad ' s army": 1,
#          "Ettelā'āt-e Banuvan": 1,
#          '9 , 246': 1,
#          '15 , 140': 1,
#          '146 , 199': 1,
#          'rod - shaped': 1,
#          '49 , 046': 2,
#          'Edwin': 1,
#          'the Fifth Élément': 2,
#          '531 , 665': 1,
#          'G-C-C sharp - d': 1,
#          "sainsbury ' s": 2,
#          '134 , 056': 1,
#          '91 , 364': 2,
#          '1910−1986': 1,
#          "america ' s Next Top model": 1,
#          'The wedge - shaped': 1,
#          "breakfast At tiffany ' s": 1,
#          's & m': 2,
#          'AK - 47': 1,
#          'lv - 1201': 1,
#          '98 , 153': 2,
#          'a . n . t . farm': 1,
#          'Romeo et Juliette': 2,
#          'mexico': 1,
#          '"La Grande Seduction "': 1,
#          'M53 motorways': 1,
#          'c . p . o . sharkey': 1,
#          "Commedia dell ' arte": 1,
#          'Easton': 1,
#          '77 , 291': 1,
#          'Tōkyō Skytree': 1,
#          "marvel ' s Agents of s . h . i . e . l . d .": 1,
#          'Kim seong - hun': 1,
#          'Tropical': 1,
#          '6 , 025': 1,
#          '1934, 1936, and 1939 – 1940': 1,
#          'Khans': 2,
#          '1981 – 1984': 1,
#          'dun eideann': 1,
#          'Tom': 2,
#          '2 , 215': 1,
#          'Guy Pearce and Catherine zeta - jones': 1,
#          'Jean-Marc vallee': 1,
#          'Mir shakil - ur - rahman': 2,
#          '691 , 893': 2,
#          'North América': 1,
#          'Gaspar de portola': 1,
#          '153 , 923': 2,
#          'Barbara Muschietti': 1,
#          'biel / bienne': 1,
#          '71 , 795': 1,
#          '4 , 836': 1,
#          'eg & g': 1,
#          'Longview': 1,
#          'Datamation. com': 1,
#          '14 , 260': 1,
#          "schindler ' s list": 1,
#          'Bella': 1,
#          '107 , 702': 1,
#          'Détroit': 1,
#          'Antonio': 1,
#          'silento': 1,
#          '3 , 861': 1,
#          'Levin oztunalı': 1,
#          'Paraguayn': 1,
#          '949 , 113': 1,
#          'Castile and leon': 1,
#          'Eugene': 1,
#          'adios amor': 1,
#          '39 , 558': 2,
#          'mid - 2010': 1,
#          "George Alan o ' dowd": 2,
#          '2005 – 2013': 1,
#          'the all - fair': 1,
#          'Dave': 1,
#          'Honolulu marathons': 1,
#          'waimanalo': 1,
#          'Cuauhtemoc Blanco': 1,
#          '149 , 194': 2,
#          'Saiyūki': 1,
#          'Funiculì, funicula': 1,
#          '15 , 264': 1,
#          '391 , 626': 1,
#          '403 , 505': 2,
#          "heaven ' s gate": 1,
#          'Ogden / Richards Triangle': 1,
#          '29 , 366': 1,
#          'Monte alban': 2,
#          '1 , 000': 1,
#          '606 , 653': 1,
#          'John Charles Fremont': 2,
#          'Elvira': 1,
#          '28 , 549': 1,
#          'n . i . b .': 1,
#          '2 , 731 , 571': 1,
#          '1 , 953': 1,
#          'Eazy-E and dr . dre': 1,
#          'born': 1,
#          '864 , 263': 2,
#          '5 , 772': 1,
#          '38 , 883': 1,
#          '4 , 334': 1,
#          '1 , 915': 1,
#          'over 60 , 000': 1,
#          'London Marathons': 1,
#          'Merle': 1,
#          '8 , 913': 1,
#          'sts - 51 - c': 2,
#          '134 , 122': 2,
#          'star - crossed': 1,
#          'Paul': 3,
#          'Driver': 1,
#          '8 , 000': 1,
#          'hotel Ritz Paris': 1,
#          'Norwegians': 1,
#          'Mary, Queen of Scots was imprisoned here in 1567 – 1568': 1,
#          'Paris': 1,
#          '87 , 411': 1,
#          '24 . 70': 1,
#          '188 , 040': 1,
#          '2009 - 2011': 1,
#          '4 , 638': 1,
#          '99 , 650': 2,
#          'mi': 1,
#          'I': 1,
#          'Polonca kovac': 1,
#          '1 , 991': 1,
#          'Koalas': 1,
#          'Stellan skarsgard': 1,
#          'Ri sol - ju': 1,
#          '$ 12 , 540 , 000': 1,
#          'Nicknamed': 1,
#          '13 , 399': 1,
#          '9 , 726': 1,
#          '7 , 095': 1,
#          'Robert hubner': 1,
#          'Lee byeong - heon': 1,
#          'Michael': 1,
#          "Societa Sportiva Calcio Napoli's": 1,
#          '7 , 323': 1,
#          'Ha Ji-won and Kim yoo - mi': 1,
#          '34 , 230': 1,
#          '2008': 1,
#          'motorhead': 2,
#          'John': 2,
#          'Monday': 1,
#          'Rokkor': 1,
#          '2003 - 05': 1,
#          '55 , 097': 2,
#          '15 , 846': 1,
#          'lennon – mccartney': 1,
#          'Ahn sang - hoon': 1,
#          "Jean-Antoine d ' anglerais": 1,
#          'F. Javier gutierrez': 1,
#          '75 , 283': 3,
#          '2 , 462': 1,
#          'Akinwande Oluwo̩lé "Wole" Babátúndé Soyinka': 1,
#          '1 , 947': 1,
#          'Gourmet': 1,
#          'Kim jong - il': 1,
#          '6 , 689': 1,
#          'mail-order brides': 1,
#          'Eveline': 1,
#          'for': 3,
#          '21 , 000': 1,
#          '1 , 696 , 923': 1,
#          '23 , 078': 2,
#          'HMS': 1,
#          'through the looking - glass': 1,
#          'Old Norse: "Sveinn Knutsson "': 1,
#          '489 – 138 – 11': 1,
#          '3 , 038': 1,
#          '1920s - 1940s': 1,
#          '59 , 515': 1,
#          '452 , 745': 1,
#          '510 , 610': 1,
#          'Sheberghān': 1,
#          'badawi': 1,
#          '76 , 728': 1,
#          "Scarlett o ' hara": 1,
#          'Paderborn, North rhine - westphalia': 1,
#          '63 , 395': 2,
#          '5 , 324': 1,
#          'usa - 126': 1,
#          'The alt - right': 1,
#          'Twitch . tv': 1,
#          "hacker ' s game": 1,
#          '2 , 712 , 945': 1,
#          '2 , 450': 2,
#          '1 , 152 , 425': 1,
#          'Teotihuacán': 1,
#          '372 , 813': 1,
#          'Michelle clark - heard': 1,
#          'Law chi - leung': 1,
#          "Ali-Shir nava ' i": 1,
#          'Tim Hortons': 1,
#          'Koontz': 1,
#          'Ólga Kurylénko': 1,
#          'Hüsker du': 1,
#          '1940 – 1941': 1,
#          'Company360': 1,
#          'prostitution': 1,
#          '74 , 262': 3,
#          'Punjabi language Bhangra singer - songwriter': 1,
#          'ab - soul': 1,
#          'indiatogether': 1,
#          '13 , 595': 1,
#          '796 , 914': 1,
#          'Yoo Seung-ho and Kang so - ra': 1,
#          '870 , 887': 2,
#          'Shunsuke': 1,
#          'Son yong - ho': 1,
#          'g . r . l .': 1,
#          'theater - in - the - round': 1,
#          '= " tunisia " > tunisia': 1,
#          'Apple': 1,
#          "The Palme d ' or": 1,
#          '40 % – 90 % ABV': 1,
#          'Cinderella': 1,
#          '689 , 775': 1,
#          'Yūki Nakai': 1,
#          'Uhm Jung-hwa and Song seung - heon': 1,
#          'Lake Charles, Louisiana, u . s . a .': 1,
#          "mid to late 50 ' s": 1,
#          "Shaquille o ' neal": 1,
#          '16 , 218': 1,
#          'amazon . com': 1,
#          'Leslie': 1,
#          'Béla bartok': 1,
#          'Chihuahuas': 1,
#          'cook': 1,
#          '850 , 996': 1,
#          'Kim ji - hoon': 1,
#          'Aleister': 1,
#          'Jonathan': 1,
#          'austria - hungary': 1,
#          '401 , 270': 1,
#          'Julio César chavez': 1,
#          '5 , 345': 2,
#          "Lac a l'Eau Claire": 1,
#          'oven - cooked agave': 1,
#          "down Wit' o . p . p": 1,
#          'La creation du monde': 1,
#          'Monographs': 1,
#          'Jo jin - kyu': 1,
#          'population of 10 , 445': 1,
#          '107 , 749': 2,
#          'Ana fernandez': 1,
#          '6 – 7': 1,
#          'universite Paris-Sorbonne, Paris iv': 1,
#          'Kim myung - min': 1,
#          'Vallee de joux': 1,
#          'Scott': 1,
#          'Léo ferre': 1,
#          'ponderosa pine, bull pine, blackjack pine, or western yellow - pine': 1,
#          '48 , 818': 3,
#          'France and the Algerian National Libération Front': 1,
#          '15 , 416': 1,
#          'Ulver': 1,
#          'Psychopsis': 1,
#          'S.N.Surendar': 1,
#          'Kong su - chang': 1,
#          '10 , 153': 1,
#          'zpizza': 1,
#          '8 . 7 – 9 . 2': 1,
#          'Dogo': 3,
#          'Fiat': 1,
#          'Jourgensen': 1,
#          'Eugenio martin': 1,
#          '1953 – 63': 1,
#          '1 , 457': 1,
#          'XXXX': 1,
#          'Vahid halilhodzic': 1,
#          'Cherokee': 1,
#          'Pythagoreanism': 1,
#          '19 , 375': 1,
#          'Who': 1,
#          "rocko ' s Modern life": 1,
#          'Tōkyō tower': 3,
#          'Lee soo - man': 2,
#          'Djibril Diop mambety': 1,
#          'Yū Darvish': 2,
#          '66 , 588': 1,
#          "Valor and m ' onel": 1,
#          "Land O' lakes": 1,
#          'Kwak kyung - taek': 1,
#          '246 , 376': 1,
#          'Vocelli': 1,
#          'Drutakarmā dasa': 1,
#          'Opera Bastille': 1,
#          'dayuanshuai': 1,
#          '$ 500 , 000': 1,
#          '20 , 449': 1,
#          'fahrenheit 9 / 11': 1,
#          'Song il - gon': 1,
#          'Black': 1,
#          "i ' m sorry": 1,
#          'Sandra': 1,
#          'Chan Kong - sang': 1,
#          'winemaking': 1,
#          '190 , 039': 1,
#          'Boardgame': 1,
#          '11 , 261': 1,
#          'Located in Washington, d . c .': 1,
#          '61 , 481': 1,
#          'Labonte': 1,
#          '1 , 202 , 362': 1,
#          'gdansk': 1,
#          'Paulus': 1,
#          'Steinheld lowhard': 1,
#          '12 , 949': 2,
#          'Texas a & m': 2,
#          '1603 – 1607': 1,
#          'Ernst II of Saxe-Coburg - Gotha': 1,
#          "veronica ' s closet": 1,
#          'Vladimir': 1,
#          'jean - paul belmondo': 1,
#          'dialogues des carmelites': 1,
#          "don ' t You Know You're beautiful": 1,
#          'my Daughter seo - young': 1,
#          '133 , 900': 1,
#          'Peter parker / spider - man': 1,
#          '1939 – 43': 1,
#          'Sublime': 1,
#          '2007 – 2011': 1,
#          'godel , Escher, Bach: an Eternal Golden braid': 1,
#          'Long. Live. a $ ap': 1,
#          'a - yo': 1,
#          'Michael coutts - trotter': 1,
#          'Tudor music and English folk - song': 1,
#          'first school founded in the Southern United States specifically for the education of African - americans': 1,
#          '1886 – 1923': 1,
#          'Harriet': 1,
#          'Orange s . a .': 1,
#          "can ' t Take Me home": 1,
#          '253 , 651': 2,
#          '3 , 079': 1,
#          'Young m . a': 1,
#          'Sir Winston Leonard spencer - Churchill': 1,
#          '2 , 121': 1,
#          '53 , 326': 2,
#          "Paul di ' anno": 1,
#          '18': 1,
#          'mid - 1840s': 1,
#          'New Zealander': 1,
#          'mile - High city': 1,
#          'Gong ji - young': 1,
#          '2005 – 2006': 1,
#          'Yūshin Okami': 1,
#          'Koporye': 1,
#          '27 – 17': 1,
#          '1999 – 2000': 1,
#          '65 , 890': 2,
#          "i ' ve Been Expecting you": 1,
#          '14 , 475': 1,
#          'DreamWorks Pictures and pathe': 1,
#          'Hāna highway': 1,
#          'Regionalliga Nordost': 1,
#          'hanna - barbera': 1,
#          'Adam': 1,
#          'Imi sde - or': 1,
#          'connecting': 1,
#          'Aside': 1,
#          '3 , 677': 1,
#          'They': 1,
#          '539 , 057': 1,
#          'anglo - Saxon chronicle': 1,
#          'Queen Marie jose': 1,
#          'l . a . law': 1,
#          'Park young - hoon': 2,
#          'Petra kvitova': 1,
#          'Pete': 1,
#          'only': 1,
#          '8 , 200': 1,
#          'from 1973 – 78': 1,
#          'honshu': 1,
#          'El Nino': 1,
#          '18 , 176': 1,
#          '4 , 255': 1,
#          'Georgy': 1,
#          'Ryūichi Sakamoto': 1,
#          'klas - tv': 1,
#          '9 , 672': 2,
#          'Leonid': 1,
#          'cuso ( ho )': 1,
#          '2 – 9': 1,
#          'Siksika': 1,
#          'Río Negro and neuquen': 1,
#          'lashkar - e - taiba': 1,
#          '12 , 018': 1,
#          '109 , 565': 1,
#          'Robert gascoyne - cecil': 1,
#          '30 , 316': 2,
#          "you ' re Makin' Me high": 1,
#          '5 , 242': 1,
#          'Iannis': 1,
#          'João': 1,
#          'Shin sang - ok': 1,
#          '1 , 766 , 184': 1,
#          'Margot wolk': 1,
#          '1754 – 63': 1,
#          'Astérix at the Olympic Games': 1,
#          '139 , 966': 2,
#          'Trinidadian': 1,
#          '472 , 522': 1,
#          'Philippe Clicquot - muiron': 1,
#          'Kool a . d': 1,
#          'Mahidol': 1,
#          '2 , 205': 1,
#          'Karlsruhe, baden - wurttemberg': 1,
#          'mheg - 5': 1,
#          '2 , 072': 1,
#          'Stanisława': 1,
#          'companies': 1,
#          '677 , 116': 1,
#          'mistico': 1,
#          '21 , 177': 1,
#          'Lee doo - yong': 1,
#          'spider - man': 1,
#          'Anthony Gonzalez, Yann Gonzalez, Morgan Kibby and Justin meldal - johnsen': 1,
#          '13 , 884': 1,
#          'Patrice chereau': 1,
#          '185 , 079': 1,
#          "grey ' s anatomy": 1,
#          'Bole2Harlem': 1,
#          'non - classical': 1,
#          'alt - j': 1,
#          'Jarabe tapatio': 1,
#          'University of Michigania': 1,
#          'eight - lane': 1,
#          '13 , 509': 1,
#          'Juan Diaz': 1,
#          'hunno - bulgarian': 1,
#          'Stuttgart, baden - wurttemberg': 1,
#          'Yum Jung-ah and Park hyuk - kwon': 1,
#          'Sheikh Fahad al - sabah': 1,
#          'According': 1,
#          'Zimbabwean': 1,
#          'Genesis 2 – 3': 1,
#          'Weatherford': 1,
#          '331 , 298': 1,
#          'reduce': 1,
#          'ferencvaros': 1,
#          'goalkeepers': 1,
#          'Leverkusen, North rhine - westphalia': 1,
#          '2 , 144': 1,
#          'The television series "MacGyver" ( 1985 – 1992 )': 1,
#          "Madeleine l ' engle": 1,
#          'ra . one': 1,
#          'Curtis': 1,
#          'yippee - ki - yay , motherfucker': 1,
#          'RiFF': 1,
#          'Kim dae - woo': 1,
#          'México': 1,
#          'Hosni Mubārak': 1,
#          "L'enfant et les sortileges": 1,
#          "nobody ' s fool": 1,
#          'p': 1,
#          'Bang si - hyuk': 1,
#          '9 , 180': 1,
#          '947 , 890': 1,
#          ...})

# %%
indices_with_0_em[:10]
# Out:
# [190, 262, 346, 384, 389, 410, 425, 443, 507, 513]

# %%
idx = 28
print("True answer: {}".format(raw_data['answer_string'][raw_data['question_indices'][idx]]))
print("Predicted: {}".format(pred_answers[idx]))
# Out:
# True answer: no
# Predicted: no

# %% [raw]
# Before:
# {'em': 0.8507625272331155,
#  'f1': 0.8829547659495811,
#  'precision': 0.8917491765224597,
#  'recall': 0.8856623901195112}
#
# After:
# {'em': 0.9428104575163399,
#  'f1': 0.9429711897882151,
#  'precision': 0.9450912309368191,
#  'recall': 0.942804895474842}

# %%
num_yes = 0
num_no = 0
num_span = 0
for i in raw_data["yes_no_span"]:
    if(i==0):
        num_yes += 1
    elif(i==1):
        num_no += 1
    else:
        num_span += 1

# %%
print("Num yes: ", num_yes)
print("Num no: ", num_no)
print("Num span: ", num_span)
print("Num yes + num no: ", num_yes+num_no)
# Out:
# Num yes:  2748
# Num no:  2733
# Num span:  84846
# Num yes + num no:  5481

# %%
print("Fraction of yes/no questions in data: ",(num_yes+num_no)/len(raw_data['yes_no_span']))
# Out:
# Fraction of yes/no questions in data:  0.06067953103723139
